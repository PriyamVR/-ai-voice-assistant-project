# %%
# !pip install SpeechRecognition # ✅ SpeechRecognition লাইব্রেরি ইনস্টল করা হচ্ছে, যা অডিও থেকে টেক্সট রূপান্তরের জন্য ব্যবহৃত হয়

# %%
# !pip install pydub # ✅ pydub লাইব্রেরি ইনস্টল করা হচ্ছে, যা অডিও ফাইল প্রক্রিয়াকরণের জন্য ব্যবহৃত হয়

# %%
# !pip install pyttsx3 # ✅ pyttsx3 লাইব্রেরি ইনস্টল করা হচ্ছে, যা টেক্সটকে স্পিচে রূপান্তরের (Text-to-Speech) জন্য ব্যবহৃত হয়

# %%
# !pip install comtypes # ✅ comtypes লাইব্রেরি ইনস্টল করা হচ্ছে, যা Windows COM অবজেক্ট ম্যানেজমেন্টের জন্য ব্যবহৃত হয়

# %%
# ✅ SpeechRecognition ইমপোর্ট করা হচ্ছে, যা অডিও থেকে টেক্সট রূপান্তরের জন্য ব্যবহৃত হয়
import speech_recognition as sr

# ✅ pydub লাইব্রেরির AudioSegment ইমপোর্ট করা হচ্ছে, যা অডিও ফাইল প্রক্রিয়াকরণের জন্য ব্যবহৃত হয়
from pydub import AudioSegment

# ✅ pydub লাইব্রেরির playback ইমপোর্ট করা হচ্ছে, যা অডিও ফাইল প্লে করার জন্য ব্যবহৃত হয়
from pydub.playback import play

# ✅ OS মডিউল ইমপোর্ট করা হচ্ছে, যা অপারেটিং সিস্টেম সম্পর্কিত কাজের জন্য ব্যবহৃত হয়
import os

# ✅ sys মডিউল ইমপোর্ট করা হচ্ছে, যা সিস্টেম-লেভেল অপারেশন পরিচালনার জন্য ব্যবহৃত হয়
import sys

# ✅ wave মডিউল ইমপোর্ট করা হচ্ছে, যা WAV অডিও ফাইল প্রক্রিয়াকরণের জন্য ব্যবহৃত হয়
import wave

# ✅ IPython.display ইমপোর্ট করা হচ্ছে, যা নোটবুক পরিবেশে মিডিয়া ফাইল দেখানোর জন্য ব্যবহৃত হয়
import IPython.display as ipd

# ✅ tkinter ইমপোর্ট করা হচ্ছে, যা GUI ফাইল ডায়ালগ তৈরি করার জন্য ব্যবহৃত হয়
import tkinter as tk

# ✅ tkinter এর filedialog ইমপোর্ট করা হচ্ছে, যা ফাইল ব্রাউজিং ও নির্বাচন করার জন্য ব্যবহৃত হয়
from tkinter import filedialog

# %%
# ✅ SpeechRecognition ইমপোর্ট করা হচ্ছে, যা অডিও থেকে টেক্সট রূপান্তরের জন্য ব্যবহৃত হয়
import speech_recognition as sr

# ✅ pydub লাইব্রেরির AudioSegment ইমপোর্ট করা হচ্ছে, যা অডিও ফাইল প্রক্রিয়াকরণের জন্য ব্যবহৃত হয়
from pydub import AudioSegment

# ✅ OS মডিউল ইমপোর্ট করা হচ্ছে, যা অপারেটিং সিস্টেম সম্পর্কিত কাজের জন্য ব্যবহৃত হয়
import os

# ✅ sys মডিউল ইমপোর্ট করা হচ্ছে, যা সিস্টেম-লেভেল অপারেশন পরিচালনার জন্য ব্যবহৃত হয়
import sys

# ✅ webbrowser মডিউল ইমপোর্ট করা হচ্ছে, যা ওয়েবসাইট লোড ও ব্রাউজারে খুলতে ব্যবহৃত হয়
import webbrowser

# ✅ IPython.display ইমপোর্ট করা হচ্ছে, যা নোটবুক পরিবেশে মিডিয়া ফাইল দেখানোর জন্য ব্যবহৃত হয়
import IPython.display as ipd

# ✅ tkinter ইমপোর্ট করা হচ্ছে, যা GUI ফাইল ডায়ালগ তৈরি করার জন্য ব্যবহৃত হয়
import tkinter as tk

# ✅ tkinter এর filedialog ইমপোর্ট করা হচ্ছে, যা ফাইল ব্রাউজিং ও নির্বাচন করার জন্য ব্যবহৃত হয়
from tkinter import filedialog

# ✅ pyttsx3 ইমপোর্ট করা হচ্ছে, যা টেক্সট-টু-স্পিচ (Text-to-Speech) ফাংশনালিটির জন্য ব্যবহৃত হয়
import pyttsx3

# ✅ requests লাইব্রেরি ইমপোর্ট করা হচ্ছে, যা HTTP অনুরোধ পাঠানোর জন্য ব্যবহৃত হয়
import requests

# ✅ BeautifulSoup ইমপোর্ট করা হচ্ছে, যা ওয়েব স্ক্র্যাপিং ও HTML ডেটা বিশ্লেষণের জন্য ব্যবহৃত হয়
from bs4 import BeautifulSoup

# %%
# ✅ pyttsx3 লাইব্রেরি ইনস্টল করা হচ্ছে, যা টেক্সটকে স্পিচে রূপান্তরের (Text-to-Speech) জন্য ব্যবহৃত হয়
# !pip install pyttsx3

# ✅ espeak ইনস্টল করা হচ্ছে, যা Linux-এ টেক্সট-টু-স্পিচ (TTS) ফিচার চালানোর জন্য ব্যবহৃত হয়
# !sudo apt install espeak # Install espeak

# ✅ pyttsx3 লাইব্রেরি ইমপোর্ট করা হচ্ছে, যা অফলাইন টেক্সট-টু-স্পিচ ফাংশনালিটির জন্য ব্যবহৃত হয়
import pyttsx3

# ✅ Text-to-Speech (TTS) সেটআপ করা হচ্ছে
# ✅ 'sapi5' এর পরিবর্তে 'espeak' ব্যবহার করা হচ্ছে কারণ গুগল কোলেভ
engine = pyttsx3.init('espeak')

# ✅ উপলব্ধ ভয়েস তালিকা থেকে প্রথম ভয়েস সেট করা হচ্ছে
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)

def speak(audio):
    """✅ Text-to-Speech ফাংশন, যা অ্যাসিস্ট্যান্টকে কথা বলাবে"""
    engine.say(audio)
    engine.runAndWait()
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# espeak is already the newest version (1.48.15+dfsg-3).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# ✅ GUI দিয়ে লোকাল ফাইল সিলেক্ট করার ফাংশন
def select_audio_file():
    """✅ টিকিন্টার (tkinter) GUI ব্যবহার করে লোকাল অডিও ফাইল নির্বাচন করা হচ্ছে"""
    root = tk.Tk()
    root.withdraw()  # ✅ GUI উইন্ডো হাইড করে রাখবে
    file_path = filedialog.askopenfilename(title="Select an audio file",
                                           filetypes=[("Audio Files", "*.wav;*.mp3")])
    return file_path

# ✅ ipywidgets লাইব্রেরি ইনস্টল করা হচ্ছে, যা Jupyter ও Colab-এর জন্য ইন্টারেক্টিভ UI তৈরি করতে ব্যবহৃত হয়
# !pip install ipywidgets

# ✅ IPython.display ইমপোর্ট করা হচ্ছে, যা মিডিয়া ও UI উপাদান প্রদর্শনের জন্য ব্যবহৃত হয়
from IPython.display import display
import ipywidgets as widgets
from IPython.display import display, Audio

def select_audio_file():
    """✅ IPython-এর ফাইল আপলোড উইজেট ব্যবহার করে অডিও ফাইল নির্বাচন করা হচ্ছে"""

    uploader = widgets.FileUpload(
        accept='.wav, .mp3',  # ✅ শুধুমাত্র .wav এবং .mp3 ফাইল অনুমোদিত
        multiple=False  # ✅ একবারে শুধুমাত্র একটি ফাইল আপলোড করা যাবে
    )

    display(uploader)

    # ✅ ইউজার ফাইল আপলোড না করা পর্যন্ত অপেক্ষা করবে
    while not uploader.value:
        pass  # ✅ এই লুপ চালু থাকবে যতক্ষণ না ইউজার ফাইল আপলোড করে

    # ✅ আপলোড করা ফাইলের ডাটা সংগ্রহ
    uploaded_file = uploader.value[0]  # ✅ প্রথম আপলোডকৃত ফাইল গ্রহণ করা হচ্ছে

    # ✅ আপলোড করা ফাইল বর্তমান ডিরেক্টরিতে সংরক্ষণ করা হচ্ছে
    with open(uploaded_file['name'], 'wb') as f:
        f.write(uploaded_file['content'])

    return uploaded_file['name']

# ✅ Google Colab-এর জন্য ফাইল আপলোড ফাংশন
from google.colab import files

# ✅ ইউজার থেকে অডিও ফাইল আপলোড করানোর জন্য
uploaded = files.upload()

# ✅ আপলোড করা ফাইলের নাম সংগ্রহ করা হচ্ছে
file_name = list(uploaded.keys())[0]
print(f"Uploaded file: {file_name}")
# Out:
# ...
#      <input type="file" id="files-2b2f9c11-049a-4248-a1b9-3f0eeb949556" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b2f9c11-049a-4248-a1b9-3f0eeb949556">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ✅ MP3 হলে WAV-এ কনভার্ট করা হচ্ছে, কারণ SpeechRecognition লাইব্রেরি WAV ফাইল ভালোভাবে প্রসেস করতে পারে
if file_name.endswith('.mp3'):
    sound = AudioSegment.from_mp3(file_name)  # ✅ MP3 ফাইল লোড করা হচ্ছে
    file_name_wav = file_name.replace('.mp3', '.wav')  # ✅ নতুন ফাইল নাম তৈরি করা হচ্ছে
    sound.export(file_name_wav, format="wav")  # ✅ MP3 কে WAV ফরম্যাটে কনভার্ট করা হচ্ছে
    print(f"Converted {file_name} to {file_name_wav}")  # ✅ রূপান্তর সফল হলে মেসেজ দেখাবে
else:
    file_name_wav = file_name  # ✅ যদি MP3 না হয়, তাহলে ফাইল নেম অপরিবর্তিত থাকবে
# Out:
# Converted blood (1).mp3 to blood (1).wav

# %%
# ✅ Speech Recognition সেটআপ করা হচ্ছে, যা অডিও থেকে টেক্সট রূপান্তরের জন্য ব্যবহৃত হয়
recognizer = sr.Recognizer()

# %%
# ✅ অডিও ফাইল থেকে স্পিচ রেকগনাইজ করা হচ্ছে
with sr.AudioFile(file_name_wav) as source:
    print("Processing audio file...")  # ✅ প্রক্রিয়াকরণ শুরু হচ্ছে
    audio = recognizer.record(source)  # ✅ সম্পূর্ণ অডিও ফাইল রেকর্ড করা হচ্ছে
# Out:
# Processing audio file...

# %%
# ✅ wikipedia লাইব্রেরি ইনস্টল করা হচ্ছে, যা Wikipedia থেকে তথ্য সংগ্রহের জন্য ব্যবহৃত হয়
# !pip install wikipedia

# ✅ SpeechRecognition, webbrowser, requests এবং wikipedia ইমপোর্ট করা হচ্ছে
import speech_recognition as sr  # ✅ অডিও থেকে টেক্সট রূপান্তরের জন্য
import webbrowser  # ✅ ওয়েবসাইট খোলার জন্য
import requests  # ✅ HTTP অনুরোধ পাঠানোর জন্য
import wikipedia  # ✅ উইকিপিডিয়া থেকে তথ্য সংগ্রহের জন্য

# ✅ Text-to-Speech ফাংশন, যা অ্যাসিস্ট্যান্টকে কথা বলাবে
def speak(text):
    print(f"🗣 {text}")

# ✅ DuckDuckGo API ব্যবহার করে প্রশ্নের উত্তর খোঁজার ফাংশন
def search_duckduckgo(query):
    """✅ DuckDuckGo API ব্যবহার করে প্রশ্নের উত্তর খোঁজা হচ্ছে"""
    search_url = f"https://api.duckduckgo.com/?q={query}&format=json"
    response = requests.get(search_url)
    data = response.json()

    if "AbstractText" in data and data["AbstractText"]:
        return data["AbstractText"]
    else:
        return "Sorry, I couldn't find the answer."

# ✅ উইকিপিডিয়া API ব্যবহার করে উত্তর আনার ফাংশন
def search_wikipedia(query):
    """✅ উইকিপিডিয়া API ব্যবহার করে উত্তর খোঁজা হচ্ছে"""
    try:
        result = wikipedia.summary(query, sentences=2)
        return result
    except wikipedia.exceptions.DisambiguationError as e:
        return f"Multiple results found: {e.options[:5]}"
    except wikipedia.exceptions.PageError:
        return "Sorry, I couldn't find the answer."

# ✅ SpeechRecognition সেটআপ করা হচ্ছে
recognizer = sr.Recognizer()

try:
    # ✅ অডিও ফাইল থেকে স্পিচ রেকগনাইজ করা হচ্ছে
    print("Recognizing Speech...")
    with sr.AudioFile(file_name_wav) as source:
        audio = recognizer.record(source)

    # ✅ ইংরেজি ও বাংলা উভয় ভাষায় স্পিচ রিকগনাইজ করা হচ্ছে
    text_en = recognizer.recognize_google(audio, language='en-US')
    text_bn = recognizer.recognize_google(audio, language='bn-BD')
    detected_text = text_en if text_en else text_bn

    print(f"✅ Recognized English: {text_en}")
    print(f"✅ Recognized Bangla: {text_bn}")
    print(f"📝 Final Detected Speech: {detected_text}")

    if detected_text:
        # ✅ ওয়েবসাইট নেভিগেশন কমান্ড চেক করা হচ্ছে
        commands = {
            "go to google": "https://www.google.com",
            "go to youtube": "https://www.youtube.com",
            "go to facebook": "https://www.facebook.com",
            "go to wikipedia": "https://www.wikipedia.org",
            "গুগলে যাও": "https://www.google.com",
            "ইউটিউবে যাও": "https://www.youtube.com",
            "ফেসবুকে যাও": "https://www.facebook.com",
            "উইকিপিডিয়াতে যাও": "https://www.wikipedia.org"
        }

        for command, url in commands.items():
            print(f"🔍 Checking Command: '{command}' in '{detected_text.lower()}'")
            if command in detected_text.lower():
                print(f"✅ Match Found: {command}, Opening {url}")
                speak(f"Opening {url}")
                webbrowser.open(url)
                break
        else:
            # ✅ প্রশ্ন হলে DuckDuckGo API ব্যবহার করে উত্তর খোঁজা হচ্ছে
            speak("Searching for the answer...")
            answer = search_duckduckgo(detected_text)

            if answer and answer != "Sorry, I couldn't find the answer.":
                print(f"✅ DuckDuckGo Answer: {answer}")
                speak(answer)
            else:
                # ✅ যদি DuckDuckGo উত্তর না পায়, তাহলে উইকিপিডিয়া ব্যবহার করা হবে
                print("❌ Couldn't find the answer. Trying Wikipedia...")
                answer = search_wikipedia(detected_text)

                if answer and answer != "Sorry, I couldn't find the answer.":
                    print(f"✅ Wikipedia Answer: {answer}")
                    speak(answer)
                else:
                    print("❌ Sorry, I couldn't find the answer.")
                    speak("Sorry, I couldn't find the answer.")

except sr.UnknownValueError:
    print("❌ Could not understand the audio.")
    speak("I could not understand your speech.")
except sr.RequestError as e:
    print(f"❌ Error connecting to Google Speech Recognition API: {e}")
    speak("There was an error connecting to Google services.")
except Exception as e:
    print(f"❌ Error Occurred: {e}")
    speak("An error occurred while processing.")
# Out:
# ...
# Recognizing Speech...
# ✅ Recognized English: what is blood color
# ✅ Recognized Bangla: হোয়ার ইজ ওয়ান
# 📝 Final Detected Speech: what is blood color
# 🔍 Checking Command: 'go to google' in 'what is blood color'
# 🔍 Checking Command: 'go to youtube' in 'what is blood color'
# 🔍 Checking Command: 'go to facebook' in 'what is blood color'
# 🔍 Checking Command: 'go to wikipedia' in 'what is blood color'
# 🔍 Checking Command: 'গুগলে যাও' in 'what is blood color'
# 🔍 Checking Command: 'ইউটিউবে যাও' in 'what is blood color'
# 🔍 Checking Command: 'ফেসবুকে যাও' in 'what is blood color'
# 🔍 Checking Command: 'উইকিপিডিয়াতে যাও' in 'what is blood color'
# 🗣 Searching for the answer...
# ❌ Couldn't find the answer. Trying Wikipedia...
# ✅ Wikipedia Answer: Carmine color is the general term for some deep red colors that are very slightly purplish but are generally slightly closer to red than the color crimson is. Some rubies are colored the color shown below as rich carmine.
# ...

# %%
# Colab ব্যবহার করলে লিংক ম্যানুয়ালি ক্লিক কর (Colab ব্রাউজার খুলতে দেয় না)।
import IPython
IPython.display.display(IPython.display.HTML(f'<a href="{url}" target="_blank">Click here to open {url}</a>'))
# Out:
# <a href="https://www.wikipedia.org" target="_blank">Click here to open https://www.wikipedia.org</a>

# %%
# ✅ তুমি যে কমান্ড টি করেছিলে মানে input
print("\n🔊 Playing the uploaded audio...")
ipd.display(ipd.Audio(file_name_wav))
# Out:
# 🔊 Playing the uploaded audio...
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#voice assistant যে আন্সার দিবে বা output

# !pip install gTTS  # ✅ gTTS (Google Text-to-Speech) লাইব্রেরি ইন্সটল করা হচ্ছে

from gtts import gTTS  # ✅ gTTS লাইব্রেরি থেকে gTTS ক্লাস ইমপোর্ট করা হচ্ছে
import os  # ✅ অপারেটিং সিস্টেম সম্পর্কিত কাজের জন্য os মডিউল ইমপোর্ট করা হচ্ছে
import IPython.display as ipd  # ✅ Jupyter Notebook-এ অডিও প্লে করার জন্য IPython.display ইমপোর্ট করা হচ্ছে

def speak(audio):
    """✅ Google Text-to-Speech (gTTS) ব্যবহার করে অডিও তৈরি করা হচ্ছে"""
    tts = gTTS(text=audio, lang="en")
    tts.save("output.mp3")
    # ✅ তৈরি করা ফাইল প্লে করা হচ্ছে
    ipd.display(ipd.Audio("output.mp3"))
# ✅ অডিও প্লে করা হচ্ছে
speak(answer)
# Out:
# ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# ✅ GUI বন্ধ করার জন্য ব্যবহারকারীর ইনপুট চাওয়া হচ্ছে, যাতে স্ক্রিপ্ট হঠাৎ বন্ধ না হয়ে যায়
input("\nPress Enter to exit...")
# Out:
# Press Enter to exit...
# ''
